# %% [markdown]
# <a href="https://colab.research.google.com/github/marclassagne/Assess/blob/master/TCC_Leticia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import plotly
import plotly.graph_objects as go
import seaborn as sns
import matplotlib as mpl
import dateutil
import matplotlib.gridspec as gridspec
import matplotlib.collections
import scipy
import pylab
import matplotlib.cm as cm
from matplotlib.legend import Legend
import matplotlib.ticker as ticker


from google.colab import drive
drive.mount('/content/drive')
from pandas import read_csv
plt.style.use('ggplot')
np_random = np.random.default_rng()
from plotly.subplots import make_subplots
sns.set_theme(style="darkgrid")
from openpyxl import Workbook
from openpyxl.utils.dataframe import dataframe_to_rows
from matplotlib.ticker import MaxNLocator, FormatStrFormatter
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Análise da malha

#Importação dos arquivos do google drive
dfngm1 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento3/malha1.csv') #Malha 1
dfngm2 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento3/malha2.csv') #Malha 2
dfngm3 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento3/malha3.csv') #Malha 3
dfngm4 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento3/malha4.csv') #Malha 4
dfngm5 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento3/malha5.csv') #Malha 5
dfngm6 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento3/malha6.csv') #Malha 6
dfngm7 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento3/malha7.csv') #Malha 7
dfngm8 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento3/malha8.csv') #Malha 8
dfngm9 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento3/malha9.csv') #Malha 9
dfngm10 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento3/malha10.csv') #Malha 10
dfngm11 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento3/malha11.csv') #Malha 11

#Definição dos pontos e ajuste para que a pressão inicial seja P_atm
xm1=dfngm1['Time']
ym1=dfngm1['med(pa)'] - 94675

xm2=dfngm2['Time']
ym2=dfngm2['med(pa)'] - 94675

xm3=dfngm3['Time']
ym3=dfngm3['med(pa)'] - 94675

xm4=dfngm4['Time']
ym4=dfngm4['med(pa)'] - 94675

xm5=dfngm5['Time']
ym5=dfngm5['med(pa)'] - 94675

xm6=dfngm6['Time']
ym6=dfngm6['med(pa)'] - 94675

xm7=dfngm7['Time']
ym7=dfngm7['med(pa)'] - 94675

xm8=dfngm8['Time']
ym8=dfngm8['med(pa)'] - 94675

xm9=dfngm9['Time']
ym9=dfngm9['med(pa)'] - 94675

xm10=dfngm10['Time']
ym10=dfngm10['med(pa)'] - 94675

xm11=dfngm11['Time']
ym11=dfngm11['med(pa)'] - 94675

#Plotar o grafico
plt.plot(xm1, ym1, label='Malha 1', linewidth = 1.2)
plt.plot(xm2, ym2, label='Malha 2', linewidth = 1.2)
plt.plot(xm3, ym3, label='Malha 3', linewidth = 1.2)
plt.plot(xm4, ym4, label='Malha 4', linewidth = 1.2)
plt.plot(xm5, ym5, label='Malha 5', linewidth = 1.2)
plt.plot(xm6, ym6, label='Malha 6', linewidth = 1.2)
plt.plot(xm7, ym7, label='Malha 7', linewidth = 1.2)
plt.plot(xm8, ym8, label='Malha 8', linewidth = 1.2)
plt.plot(xm9, ym9, label='Malha 9', linewidth = 1.2)
plt.plot(xm10, ym10, label='Malha 10', linewidth = 1.2)
plt.plot(xm11, ym11, label='Malha 11', linewidth = 1.2)

#configurações do grafico
plt.legend(loc='lower left',fontsize='8')
plt.title('Pressão acústica média')
plt.xlabel('Time [s] ')
plt.ylabel('Acoustic pressure [Pa]')
# Out:
# Text(0, 0.5, 'Acoustic pressure [Pa]')

# %%
#Casos 1, 2 e 3 para  2.78*10e5 Pa e 4.63*10e5 Pa

#Importação dos arquivos do google drive
dfng1 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento2/resultados90caso1.csv')
dfng2 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento2/resultados90caso2.csv')
dfng3 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento2/resultados90caso3.csv')

dfng4 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento2/resultados150caso1.csv')
dfng5 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento2/resultados150caso2.csv')
dfng6 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento2/resultados150caso3.csv')

#Definição dos pontos
x1=dfng1['Time']
y1=dfng1['med(pa)']

x1a=dfng1['Time']
y1a=dfng1['max(pa)']

x1b=dfng1['Time']
y1b=dfng1['min(pa)']

x1c=dfng1['Time']
y1c=dfng1['avg(pa)']

x2=dfng2['Time']
y2=dfng2['med(pa)']

x2a=dfng2['Time']
y2a=dfng2['max(pa)']

x2b=dfng2['Time']
y2b=dfng2['min(pa)']

x2c=dfng2['Time']
y2c=dfng2['avg(pa)']

x3=dfng3['Time']
y3=dfng3['med(pa)']

x3a=dfng3['Time']
y3a=dfng3['max(pa)']

x3b=dfng3['Time']
y3b=dfng3['min(pa)']

x3c=dfng3['Time']
y3c=dfng3['avg(pa)']

x4=dfng4['Time']
y4=dfng4['med(pa)']

x4a=dfng4['Time']
y4a=dfng4['max(pa)']

x4b=dfng4['Time']
y4b=dfng4['min(pa)']

x4c=dfng4['Time']
y4c=dfng4['avg(pa)']

x5=dfng5['Time']
y5=dfng5['med(pa)']

x5a=dfng5['Time']
y5a=dfng5['max(pa)']

x5b=dfng5['Time']
y5b=dfng5['min(pa)']

x5c=dfng5['Time']
y5c=dfng5['avg(pa)']

x6=dfng6['Time']
y6=dfng6['med(pa)']

x6a=dfng6['Time']
y6a=dfng6['max(pa)']

x6b=dfng6['Time']
y6b=dfng6['min(pa)']

x6c=dfng6['Time']
y6c=dfng6['avg(pa)']

# %%
#Plotar o grafico dos  valores médios de pa
plt.plot(x1, y1, label='caso 1 - 2.78*10e5 Pa', linewidth=0.6)
plt.plot(x2, y2, label='caso 2 - 2.78*10e5 Pa', linewidth=0.6)
plt.plot(x3, y3, label='caso 3 - 2.78*10e5 Pa', linewidth=0.6)
plt.plot(x4, y4, label='caso 1 - 4.63*10e5 Pa', linewidth=0.6)
plt.plot(x5, y5, label='caso 2 - 4.63*10e5 Pa', linewidth=0.6)
plt.plot(x6, y6, label='caso 3 - 4.63*10e5 Pa', linewidth=0.6)

#configurações do grafico
plt.xlim(0, 0.005)
#plt.ylim(101375, 101425)
plt.xlabel('Time [s]')
plt.ylabel('Acoustic Pressure [Pa]')
plt.title('Pressão acústica média no tempo')
plt.legend(loc='upper left',fontsize='8')

# %%
#Plotar o grafico dos valores max e min de pa
plt.plot(x1a, y1a, label='Pa_max caso 1 - 2.78*10e5 Pa', linewidth=0.6)
plt.plot(x1b, y1b, label='Pa_min caso 1 - 2.78*10e5 Pa', linewidth=0.6)
plt.plot(x2a, y2a, label='Pa_max caso 2 - 2.78*10e5 Pa', linewidth=0.6)
plt.plot(x2b, y2b, label='Pa_min caso 2 - 2.78*10e5 Pa', linewidth=0.6)
plt.plot(x3a, y3a, label='Pa_max caso 3 - 2.78*10e5 Pa', linewidth=0.6)
plt.plot(x3b, y3b, label='Pa_min caso 3 - 2.78*10e5 Pa', linewidth=0.6)
plt.plot(x4a, y4a, label='Pa_max caso 1 - 4.63*10e5 Pa', linewidth=0.6)
plt.plot(x4b, y4b, label='Pa_min caso 1 - 4.63*10e5 Pa', linewidth=0.6)
plt.plot(x5a, y5a, label='Pa_max caso 2 - 4.63*10e5 Pa', linewidth=0.6)
plt.plot(x5b, y5b, label='Pa_min caso 2 - 4.63*10e5 Pa', linewidth=0.6)
plt.plot(x6a, y6a, label='Pa_max caso 3 - 4.63*10e5 Pa', linewidth=0.6)
plt.plot(x6b, y6b, label='Pa_min caso 3 - 4.63*10e5 Pa', linewidth=0.6)

#configurações do grafico
plt.xlim(0, 0.005)
#plt.ylim(101375, 101425)
plt.xlabel('Time [s]')
plt.ylabel('Acoustic Pressure [Pa]')
plt.title('Pressão acústica max e min no tempo')
plt.legend(loc='upper right',fontsize='6')

# %%
#Plotar o grafico dos valores médios de pa para os casos 1, 2 e 3 para 2.78*10e5 Pa
plt.plot(x1, y1, label='caso 1 - 2.78*10e5 Pa', linewidth=0.7)
#plt.plot(x11, y11)
#plt.plot(x12, y12)
#plt.plot(x13, y13, label='caso 1')
plt.plot(x2, y2, label='caso 2 - 2.78*10e5 Pa', linewidth=0.7) #pa menores que os casos 1 e 3
#plt.plot(x21, y21)
#plt.plot(x22, y22)
#plt.plot(x23, y23, label='caso 2')
plt.plot(x3, y3, label='caso 3 - 2.78*10e5 Pa', linewidth=0.7) #mesmo comportamento do caso 1
#plt.plot(x31, y31)
#plt.plot(x32, y32)
#plt.plot(x33, y33, label='caso 3')

#configurações do grafico
plt.xlim(0, 0.005)
#plt.ylim(101375, 101425)
plt.xlabel('Time [s]')
plt.ylabel('Acoustic Pressure [Pa]')
plt.title('Pressão acústica no tempo - Pulso de 2.78*10e5 Pa')
plt.legend(loc='lower right',fontsize='8')

# %%
#Plotar o grafico dos valores médios de pa para os casos 1, 2 e 3 para 2.78*10e5 Pa - ZOOM
plt.plot(x1, y1, label='caso 1 - 2.78*10e5 Pa', linewidth=0.7)
#plt.plot(x11, y11)
#plt.plot(x12, y12)
#plt.plot(x13, y13, label='caso 1')
plt.plot(x2, y2, label='caso 2 - 2.78*10e5 Pa', linewidth=0.7) #pa menores que os casos 1 e 3
#plt.plot(x21, y21)
#plt.plot(x22, y22)
#plt.plot(x23, y23, label='caso 2')
plt.plot(x3, y3, label='caso 3 - 2.78*10e5 Pa', linewidth=0.7) #mesmo comportamento do caso 1
#plt.plot(x31, y31)
#plt.plot(x32, y32)
#plt.plot(x33, y33, label='caso 3')

#configurações do grafico
plt.xlim(0.002, 0.005)
#plt.ylim(101375, 101425)
plt.xlabel('Time [s]')
plt.ylabel('Acoustic Pressure [Pa]')
plt.title('Pressão acústica no tempo - Pulso de 2.78*10e5 Pa')
plt.legend(loc='lower right',fontsize='8')

# %%
#Plotar o grafico do desvio padrão
std_deviation = np.std([y1, y2, y3], axis=0)

plt.fill_between(x1, y1 - std_deviation, y1 + std_deviation, color='gray', alpha=0.1)
plt.fill_between(x2, y2 - std_deviation, y2 + std_deviation, color='gray', alpha=0.1)
plt.fill_between(x3, y3 - std_deviation, y3 + std_deviation, color='gray', alpha=0.1)

#configurações do grafico
plt.xlim(0, 0.005)
#plt.ylim(101375, 101425)
plt.xlabel('Time [s]')
plt.ylabel('Acoustic Pressure [Pa]')
plt.title('Desvio padrão dos valores de pressão acústica no tempo')
plt.legend(loc='lower right',fontsize='8')
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Plotar o grafico dos valores médios de pa para os casos 1, 2 e 3 para 4.63*10e5 Pa
plt.plot(x4, y4, label='caso 1 - 4.63*10e5 Pa', linewidth=0.3)
#plt.plot(x41, y41)
#plt.plot(x42, y42)
#plt.plot(x43, y43, label='caso 1')
plt.plot(x5, y5, label='caso 2 - 4.63*10e5 Pa', linewidth=0.3)
#plt.plot(x51, y51)
#plt.plot(x52, y52)
#plt.plot(x53, y53, label='caso 2')
plt.plot(x6, y6, label='caso 3 - 4.63*10e5 Pa', linewidth=0.3)
#plt.plot(x61, y61)
#plt.plot(x62, y62)
#plt.plot(x63, y63, label='caso 3')

#configurações do grafico
plt.xlim(0, 0.005)
#plt.ylim(101475, 101500)
plt.xlabel('Time [s]')
plt.ylabel('Acoustic Pressure [Pa]')
plt.title('Pressão acústica no tempo - Pulso de 4.63*10e5 Pa')
plt.legend(loc='lower right',fontsize='8')

# %%
#Plotar o grafico dos valores médios de pa para os casos 1, 2 e 3 para 4.63*10e5 Pa - ZOOM
plt.plot(x4, y4, label='caso 1 - 4.63*10e5 Pa', linewidth=0.3)
#plt.plot(x41, y41)
#plt.plot(x42, y42)
#plt.plot(x43, y43, label='caso 1')
plt.plot(x5, y5, label='caso 2 - 4.63*10e5 Pa', linewidth=0.3)
#plt.plot(x51, y51)
#plt.plot(x52, y52)
#plt.plot(x53, y53, label='caso 2')
plt.plot(x6, y6, label='caso 3 - 4.63*10e5 Pa', linewidth=0.3)
#plt.plot(x61, y61)
#plt.plot(x62, y62)
#plt.plot(x63, y63, label='caso 3')

#configurações do grafico
plt.xlim(0.002, 0.005)
#plt.ylim(101475, 101500)
plt.xlabel('Time [s]')
plt.ylabel('Acoustic Pressure [Pa]')
plt.title('Pressão acústica no tempo - Pulso de 4.63*10e5 Pa')
plt.legend(loc='lower right',fontsize='8')

# %%
#Plotar o grafico do desvio padrão
std_deviation2 = np.std([y1, y2, y3], axis=0)

plt.fill_between(x4, y4 - std_deviation2, y4 + std_deviation2, color='gray', alpha=0.1)
plt.fill_between(x5, y5 - std_deviation2, y5 + std_deviation2, color='gray', alpha=0.1)
plt.fill_between(x6, y6 - std_deviation2, y6 + std_deviation2, color='gray', alpha=0.1)

#configurações do grafico
plt.xlim(0, 0.005)
#plt.ylim(101375, 101425)
plt.xlabel('Time [s]')
plt.ylabel('Acoustic Pressure [Pa]')
plt.title('Desvio padrão dos valores de pressão acústica no tempo')
plt.legend(loc='lower right',fontsize='8')
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Junção dos graficos do desvio padrão em um

#Plotar o grafico do desvio padrão
std_deviation3 = np.std([y1, y2, y3], axis=0)

plt.fill_between(x1, y1 - std_deviation3, y1 + std_deviation3, color='gray', alpha=0.1)
plt.fill_between(x2, y2 - std_deviation3, y2 + std_deviation3, color='gray', alpha=0.1)
plt.fill_between(x3, y3 - std_deviation3, y3 + std_deviation3, color='gray', alpha=0.1)

std_deviation4 = np.std([y1, y2, y3], axis=0)

plt.fill_between(x4, y4 - std_deviation4, y4 + std_deviation4, color='gray', alpha=0.1)
plt.fill_between(x5, y5 - std_deviation4, y5 + std_deviation4, color='gray', alpha=0.1)
plt.fill_between(x6, y6 - std_deviation4, y6 + std_deviation4, color='gray', alpha=0.1)

#configurações do grafico
plt.xlim(0, 0.005)
#plt.ylim(101375, 101425)
plt.xlabel('Time [s]')
plt.ylabel('Acoustic Pressure [Pa]')
plt.title('Desvio padrão dos valores de pressão acústica no tempo')
# Out:
# Text(0.5, 1.0, 'Desvio padrão dos valores de pressão acústica no tempo')

# %%
#Comparação entre intensidades de pulsos

# %%
#versao 1 -Pulso = 0,277960766 Pa
#Importação dos arquivos do google drive
dfng7 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento/v1resultados90caso1.csv')
dfng8 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento/v1resultados90caso2.csv')
dfng9 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento/v1resultados90caso3.csv')

#Definição dos pontos
x7=dfng7['Time']
y7=dfng7['med(pa)'] - 94675

x8=dfng8['Time']
y8=dfng8['med(pa)'] - 94675

x9=dfng9['Time']
y9=dfng9['med(pa)'] - 94675

#Plotar o grafico
plt.plot(x7, y7, label='caso 1', linewidth=0.6)
plt.plot(x8, y8, label='caso 2', linewidth=0.6)
plt.plot(x9, y9, label='caso 3', linewidth=0.6)

#configurações do grafico
plt.xlim(0, 0.005)
plt.xlabel('Time [s]')
plt.ylabel('Acoustic pressure [Pa]')
plt.title('Pressão acústica média no tempo - Pulso = 0,277960766 Pa')
plt.legend(loc='lower left',fontsize='8')

# %%
#Plotar o grafico do desvio padrão
std_deviation5 = np.std([y7, y8, y9], axis=0)

plt.fill_between(x7, y7 - std_deviation5, y7 + std_deviation5, color='gray', alpha=0.1)
plt.fill_between(x8, y8 - std_deviation5, y8 + std_deviation5, color='gray', alpha=0.1)
plt.fill_between(x9, y9 - std_deviation5, y9 + std_deviation5, color='gray', alpha=0.1)

#configurações do grafico
plt.xlim(0, 0.005)
#plt.ylim(101375, 101425)
plt.xlabel('Time [s]')
plt.ylabel('Acoustic pressure [Pa]')
plt.title('Desvio padrão dos valores de pressão acústica no tempo')
plt.legend(loc='lower right',fontsize='8')
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#versao 2 - Pulso = 2.78*10e5 Pa
#Importação dos arquivos do google drive
dfng10 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento/v2resultados90caso1.csv')
dfng11 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento/v2resultados90caso2.csv')
dfng12 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento/v2resultados90caso3.csv')

#Definição dos pontos
x10=dfng10['Time']
y10=dfng10['med(pa)']
plt.plot(x10, y10, label='caso 1', linewidth=0.6)

x11=dfng11['Time']
y11=dfng11['med(pa)']
plt.plot(x11, y11, label='caso 2', linewidth=0.6)

x12=dfng12['Time']
y12=dfng12['med(pa)']
plt.plot(x12, y2, label='caso 3', linewidth=0.6)

#Plotar o grafico do desvio padrão

#configurações do grafico
plt.xlim(0, 0.005)
plt.xlabel('Time [s]')
plt.ylabel('Acoustic pressure [Pa]')
plt.title('Pressão acústica média no tempo - Pulso = 2.78*10e5 Pa')
plt.legend(loc='lower right',fontsize='8')

# %%
#Plotar o grafico do desvio padrão
std_deviation6 = np.std([y10, y11, y12], axis=0)

plt.fill_between(x10, y10 - std_deviation6, y10 + std_deviation6, color='gray', alpha=0.1)
plt.fill_between(x11, y11 - std_deviation6, y11 + std_deviation6, color='gray', alpha=0.1)
plt.fill_between(x12, y12 - std_deviation6, y12 + std_deviation6, color='gray', alpha=0.1)

#configurações do grafico
plt.xlim(0, 0.005)
#plt.ylim(101375, 101425)
plt.xlabel('Time [s]')
plt.ylabel('Acoustic pressure [Pa]')
plt.title('Desvio padrão dos valores de pressão acústica no tempo')
plt.legend(loc='lower right',fontsize='8')
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#versao 3 - Pulso = 2.78*10e8 Pa
#Importação dos arquivos do google drive
dfng13 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento/v3resultados90caso1.csv')
dfng14 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento/v3resultados90caso2.csv')
dfng15 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento/v3resultados90caso3.csv')

#Definição dos pontos
x13=dfng13['Time']
y13=dfng13['med(pa)']

x14=dfng14['Time']
y14=dfng14['med(pa)']

x15=dfng15['Time']
y15=dfng15['med(pa)']

#Plotar o grafico
plt.plot(x13, y13, label='caso 1', linewidth=0.6)
plt.plot(x14, y14, label='caso 2', linewidth=0.6)
plt.plot(x15, y15, label='caso 3', linewidth=0.6)

#configurações do grafico
plt.xlim(0, 0.005)
plt.xlabel('Time [s]')
plt.ylabel('Acoustic pressure [Pa]')
plt.title('Pressão acústica média no tempo - Pulso = 2.78*10e8 Pa')
plt.legend(loc='upper left',fontsize='8')

# %%
#Plotar o grafico do desvio padrão
std_deviation7 = np.std([y13, y14, y15], axis=0)

plt.fill_between(x13, y13 - std_deviation7, y13 + std_deviation7, color='gray', alpha=0.1)
plt.fill_between(x14, y14 - std_deviation7, y14 + std_deviation7, color='gray', alpha=0.1)
plt.fill_between(x15, y15 - std_deviation7, y15 + std_deviation7, color='gray', alpha=0.1)

#configurações do grafico
plt.xlim(0, 0.005)
#plt.ylim(101375, 101425)
plt.xlabel('Time [s]')
plt.ylabel('Acoustic pressure [Pa]')
plt.title('Desvio padrão dos valores de pressão acústica no tempo')
plt.legend(loc='lower right',fontsize='8')
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Junção dos graficos anteriores em um so

#versao 1
#Importação dos arquivos do google drive
dfng7 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento/v1resultados90caso1.csv')
dfng8 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento/v1resultados90caso2.csv')
dfng8 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento/v1resultados90caso3.csv')

#Gerar eixo 1
fig, ax1 = plt.subplots()

#Definição dos pontos
x7=dfng7['Time']
y7=dfng7['med(pa)'] - 94675

x8=dfng8['Time']
y8=dfng8['med(pa)'] - 94675

x9=dfng9['Time']
y9=dfng9['med(pa)'] - 94675

#Plotar o grafico
ax1.plot(x7, y7, label='caso 1', linewidth=0.6)
ax1.plot(x8, y8, label='caso 2', linewidth=0.6)
ax1.plot(x9, y9, label='caso 3', linewidth=0.6)

#versao 2
#Importação dos arquivos do google drive
dfng10 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento/v2resultados90caso1.csv')
dfng11 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento/v2resultados90caso2.csv')
dfng12 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento/v2resultados90caso3.csv')

#Definição dos pontos
x10=dfng10['Time']
y10=dfng10['med(pa)']

x11=dfng11['Time']
y11=dfng11['med(pa)']

x12=dfng12['Time']
y12=dfng12['med(pa)']

#Plotar o grafico
ax1.plot(x10, y10, label='caso 1', linewidth=0.6)
ax1.plot(x11, y11, label='caso 2', linewidth=0.6)
ax1.plot(x12, y2, label='caso 3', linewidth=0.6)

#Gerar eixo 2
ax2 = ax1.twinx()

#versao 3
#Importação dos arquivos do google drive
dfng13 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento/v3resultados90caso1.csv')
dfng14 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento/v3resultados90caso2.csv')
dfng15 = pd.read_csv('/content/drive/MyDrive/TCC_Leticia_codigos/posprocessamento/v3resultados90caso3.csv')

#Definição dos pontos
x13=dfng13['Time']
y13=dfng13['med(pa)']

x14=dfng14['Time']
y14=dfng14['med(pa)']

x15=dfng15['Time']
y15=dfng15['med(pa)']

#Plotar o grafico
ax2.plot(x13, y13, label='caso 1', linewidth=0.6)
ax2.plot(x14, y14, label='caso 2', linewidth=0.6)
ax2.plot(x15, y15, label='caso 3', linewidth=0.6)

#configurações do grafico
plt.xlim(0, 0.005)
ax1.tick_params('y', colors='blue')
ax2.tick_params('y', colors='red')
ax1.set_xlabel('Time [s]')
ax1.set_ylabel('Acoustic pressure [Pa]')
ax2.set_ylabel('Acoustic pressure [Pa]')
plt.title('Pressão acústica média no tempo - Pulso = 0,277960766 Pa')
plt.legend(loc='lower left',fontsize='8')

# %%
#Plotar o grafico do desvio padrão
std_deviation8 = np.std([y7, y8, y9], axis=0)

plt.fill_between(x7, y7 - std_deviation8, y7 + std_deviation8, color='gray', alpha=0.1)
plt.fill_between(x8, y8 - std_deviation8, y8 + std_deviation8, color='gray', alpha=0.1)
plt.fill_between(x9, y9 - std_deviation8, y9 + std_deviation8, color='gray', alpha=0.1)

std_deviation9 = np.std([y10, y11, y12], axis=0)

plt.fill_between(x10, y10 - std_deviation9, y10 + std_deviation9, color='gray', alpha=0.1)
plt.fill_between(x11, y11 - std_deviation9, y11 + std_deviation9, color='gray', alpha=0.1)
plt.fill_between(x12, y12 - std_deviation9, y12 + std_deviation9, color='gray', alpha=0.1)

std_deviation10 = np.std([y13, y14, y15], axis=0)

plt.fill_between(x13, y13 - std_deviation10, y13 + std_deviation10, color='gray', alpha=0.1)
plt.fill_between(x14, y14 - std_deviation10, y14 + std_deviation10, color='gray', alpha=0.1)
plt.fill_between(x15, y15 - std_deviation10, y15 + std_deviation10, color='gray', alpha=0.1)

#configurações do grafico
plt.xlim(0, 0.005)
#plt.ylim(101375, 101425)
plt.xlabel('Time [s]')
plt.ylabel('Acoustic pressure [Pa]')
plt.title('Desvio padrão dos valores de pressão acústica no tempo')
plt.legend(loc='lower right',fontsize='8')
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
